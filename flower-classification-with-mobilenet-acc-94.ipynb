# %% [markdown]
# <p><em style="font-family: 'Arial', sans-serif;">I'm <h2><b>MIQ<b></h2>In this notebook  <span style="font-size: 15px; color: #007BFF;">📊</span> images are classified into five floral classes: <span style="font-size: 15px; color: #FFC0CB;">🌼 chamomile</span>, <span style="font-size: 15px; color: #FF69B4;">🌷 tulip</span>, <span style="font-size: 15px; color: #FF0000;">🌹 rose</span>, <span style="font-size: 15px; color: #FFD700;">🌻 sunflower</span>, and <span style="font-size: 15px; color: #FFC0CB;">🌼 dandelion</span>. Leveraging MobileNet with transfer learning, an impressive <b>94%</b> accuracy was attained. Your <h3>upvotes❤️</h3> are appreciated!<b> </em></p><br>
#  <img src="https://i.pinimg.com/564x/20/a3/5f/20a35f9311a47a25fbb64cf5b04e7ede.jpg" alt="Flower Image" width="700" height="300">
#  <h2>Contact Me</h2>
# <ul>
#   <li><a href="https://www.kaggle.com/ibrahimqasimi">Kaggle</a></li>
#   <li><a href="https://www.linkedin.com/in/muhammad-ibrahim-qasmi-9876a1297/">LinkedIn</a></li>
#   <li><a href="oppoibrahim23@gmail.com">Gmail</a></li>
#   <li><a href="https://github.com/muhammadibrahim313">GitHub</a></li>
# </ul>

# %% [markdown]
# ## **Meta Data**
# Are you ready to embark on a journey through the mesmerizing realm of flowers? 🌸 Let's dive into a dataset brimming with the vibrant beauty of nature, containing 4242 captivating images of various floral wonders.
#
# ### Context 🌿
# This delightful collection of images captures the essence of flora from diverse sources such as Flickr, Google Images, and Yandex Images. It serves as a treasure trove for enthusiasts and researchers alike, offering a glimpse into the natural splendor of our world.
#
# ### Content 📸
# Within this dataset lie 4242 meticulously curated photographs, each a window into the enchanting world of flowers. These images are classified into five distinct classes, each representing a unique botanical marvel:
# - **Chamomile**: With its delicate white petals and golden center, the chamomile flower exudes tranquility and calm.
# - **Tulip**: A symbol of love and elegance, the tulip boasts a kaleidoscope of colors and graceful curves.
# - **Rose**: The epitome of romance and passion, the rose enchants with its velvety petals and intoxicating fragrance.
# - **Sunflower**: Radiating warmth and vitality, the sunflower stands tall with its bold, golden hues and cheerful demeanor.
# - **Dandelion**: A harbinger of wishes and dreams, the dandelion captivates with its whimsical, ethereal beauty.
#
# ### Acknowledgements✨
# Gratitude is owed to the diligent efforts of those who compiled this dataset, scraping images from various online sources. Their dedication has provided us with a valuable resource for botanical exploration and research.
#
# ## Inspiration 🌟
# Amidst this collection of floral delights lies endless potential for discovery and inspiration. From image recognition algorithms to artistic endeavors, the possibilities are as abundant as the petals in a springtime meadow. So, what kind of flower catches your eye? Dive in, explore, and let the beauty of nature inspire your imagination! 🌷✨

# %% [markdown]
# # **Table of Contents**

# %% [markdown]
# **Step 1:** Importing Libraries 📝
# [Importing Libraries](#step-1-importing-libraries)
#
# **Step 2:** Loading Dataset 📂
# [Loading Dataset](#step-2-loading-dataset)
#
# **Step 3:** Data Preparation 🛠️
# [Data Preparation](#step-3-data-preparation)
#
# **Step 4:** Creating Model 🧠
# [Creating Model](#step-4-creating-model)
#
# **Step 5:** Prediction 🎯
# [Prediction](#step-5-prediction)
#
# **Step 6:** Conclusion 📝
# [Conclusion](#step-6-conclusion)

# %% [markdown]
# # *Step 1: Importing Libraries*

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
from IPython.display import Image, display
import matplotlib.cm as cm

import tensorflow as tf 

import os
import shutil
from tqdm import tqdm
from random import shuffle

import cv2
from glob import glob

from tensorflow.keras import backend as K
import random
import albumentations as A
from sklearn.model_selection import train_test_split, StratifiedKFold

from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing.image import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.applications.efficientnet import *
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings("ignore")
print("import done")
# Out:
# 2025-10-08 07:39:25.153781: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759909165.340889      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759909165.392462      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# import done

# %% [markdown]
# # *Step 2: Loading Dataset*

# %%
image_dir = Path('/kaggle/input/flowers-recognition/flowers')

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# %% [markdown]
# ### 2.1 *Viewing Dataset*

# %%
#Viewing first 5 image
image_df.head()
# Out:
#                                             Filepath      Label
# 0  /kaggle/input/flowers-recognition/flowers/dand...  dandelion
# 1  /kaggle/input/flowers-recognition/flowers/dand...  dandelion
# 2  /kaggle/input/flowers-recognition/flowers/dand...  dandelion
# 3  /kaggle/input/flowers-recognition/flowers/dand...  dandelion
# 4  /kaggle/input/flowers-recognition/flowers/dand...  dandelion

# %%
#Viewing last 5 image
image_df.tail()
# Out:
#                                                Filepath Label
# 4312  /kaggle/input/flowers-recognition/flowers/rose...  rose
# 4313  /kaggle/input/flowers-recognition/flowers/rose...  rose
# 4314  /kaggle/input/flowers-recognition/flowers/rose...  rose
# 4315  /kaggle/input/flowers-recognition/flowers/rose...  rose
# 4316  /kaggle/input/flowers-recognition/flowers/rose...  rose

# %%
# Shuffle the DataFrame and reset index
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result
image_df.head(5)
# Out:
#                                             Filepath      Label
# 0  /kaggle/input/flowers-recognition/flowers/dand...  dandelion
# 1  /kaggle/input/flowers-recognition/flowers/rose...       rose
# 2  /kaggle/input/flowers-recognition/flowers/tuli...      tulip
# 3  /kaggle/input/flowers-recognition/flowers/rose...       rose
# 4  /kaggle/input/flowers-recognition/flowers/dais...      daisy

# %% [markdown]
# ### 2.2 *Shape of Dataset*

# %%
image_df.shape
# Out:
# (4317, 2)

# %% [markdown]
# ### 2.3 *Displaying Dataset*

# %%
# Display 20 picture of the dataset with their labels
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(15, 7),
                        subplot_kw={'xticks': [1], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# # *Step 3: Data Preparation*

# %% [markdown]
# ### 3.1 *Splitting Dataset*

# %%
train_df, test_df = train_test_split(image_df, train_size=0.9, shuffle=True, random_state=1)

# %% [markdown]
# ### 3.2 *Train Data Shape*

# %%
train_df.shape
# Out:
# (3885, 2)

# %% [markdown]
# ### 3.3 **MobilenetV2**

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

# %% [markdown]
# ### 3.4 *Train Data head and tail*

# %%
train_df.head()
# Out:
#                                                Filepath      Label
# 3808  /kaggle/input/flowers-recognition/flowers/rose...       rose
# 1858  /kaggle/input/flowers-recognition/flowers/tuli...      tulip
# 2275  /kaggle/input/flowers-recognition/flowers/rose...       rose
# 1909  /kaggle/input/flowers-recognition/flowers/dais...      daisy
# 1078  /kaggle/input/flowers-recognition/flowers/dand...  dandelion

# %%
train_df.tail()
# Out:
#                                                Filepath      Label
# 2895  /kaggle/input/flowers-recognition/flowers/rose...       rose
# 2763  /kaggle/input/flowers-recognition/flowers/tuli...      tulip
# 905   /kaggle/input/flowers-recognition/flowers/dand...  dandelion
# 3980  /kaggle/input/flowers-recognition/flowers/tuli...      tulip
# 235   /kaggle/input/flowers-recognition/flowers/rose...       rose

# %% [markdown]
# ### 3.5 *Train,validation and test Data Shape*

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 3108 validated image filenames belonging to 5 classes.
# Found 777 validated image filenames belonging to 5 classes.
# Found 432 validated image filenames belonging to 5 classes.

# %% [markdown]
# **There are 3108 training images and 777 and  432 validated are  images**

# %% [markdown]
# # *Step 4: Creating Model*

# %%
def create_model(input_shape=(224, 224, 3)):
    
    inputs = Input(input_shape)
    base_model = EfficientNetB1(input_shape=input_shape, include_top=False, classes=5)
    
    x = base_model(inputs)
    
    x = GlobalAveragePooling2D()(x)
#     x = Dropout(0.1)(x)
    
    x = Dense(56, activation='relu')(x)
    x = Dropout(0.1)(x)
    
    outputs = Dense(5, activation='sigmoid')(x)
    
    model = Model(inputs, outputs)
    
    return model
K.clear_session()

model = create_model((224, 224, 3))
# model = load_model('models/checkpoint/EfficientNetB0.h5')

metrics = [
    'accuracy',
    'AUC'
]
# Out:
# I0000 00:00:1759909199.952320      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27018416/27018416 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# ### 4.1 *Compile Model*

# %%
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=metrics)

# %% [markdown]
# ###  4.2 *Callbacks*

# %%
checkpoint_path = 'models/EfficientNetB1/model_224.h5'

callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', patience=15, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint(monitor='val_loss', mode='min', filepath=checkpoint_path, verbose=1, save_best_only=True, save_weights_only=False)
]

# %% [markdown]
# ### 4.3 *Fit Model*

# %%
# %%time
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=30,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759909282.228751     100 service.cc:148] XLA service 0x7ad7bc004900 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759909282.229595     100 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759909289.573445     100 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1759909301.160452     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759909301.353196     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759909301.863713     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759909302.071247     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759909302.469926     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759909302.678499     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759909303.250503     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759909303.501367     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1759909330.147060     100 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - AUC: 0.8902 - accuracy: 0.7201 - loss: 0.7545
# E0000 00:00:1759909368.720205      99 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759909368.909827      99 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759909369.341295      99 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1759909369.550705      99 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - AUC: 0.8907 - accuracy: 0.7210 - loss: 0.7524
# Epoch 1: val_loss improved from inf to 2.10446, saving model to models/EfficientNetB1/model_224.h5
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 209s 879ms/step - AUC: 0.8912 - accuracy: 0.7219 - loss: 0.7504 - val_AUC: 0.5021 - val_accuracy: 0.1673 - val_loss: 2.1045 - learning_rate: 0.0010
# Epoch 2/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9708 - accuracy: 0.8773 - loss: 0.3555
# Epoch 2: val_loss did not improve from 2.10446
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 186ms/step - AUC: 0.9708 - accuracy: 0.8775 - loss: 0.3551 - val_AUC: 0.5195 - val_accuracy: 0.2329 - val_loss: 3.3277 - learning_rate: 0.0010
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9860 - accuracy: 0.9430 - loss: 0.1966
# Epoch 3: val_loss did not improve from 2.10446
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 186ms/step - AUC: 0.9860 - accuracy: 0.9430 - loss: 0.1966 - val_AUC: 0.5208 - val_accuracy: 0.2239 - val_loss: 2.7345 - learning_rate: 0.0010
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - AUC: 0.9910 - accuracy: 0.9552 - loss: 0.1425
# Epoch 4: val_loss did not improve from 2.10446
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 185ms/step - AUC: 0.9910 - accuracy: 0.9551 - loss: 0.1428 - val_AUC: 0.5107 - val_accuracy: 0.2329 - val_loss: 4.4489 - learning_rate: 0.0010
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9913 - accuracy: 0.9479 - loss: 0.1464
# Epoch 5: val_loss did not improve from 2.10446
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - AUC: 0.9913 - accuracy: 0.9480 - loss: 0.1464 - val_AUC: 0.5359 - val_accuracy: 0.2329 - val_loss: 3.1182 - learning_rate: 0.0010
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9925 - accuracy: 0.9663 - loss: 0.1038
# Epoch 6: val_loss improved from 2.10446 to 1.88299, saving model to models/EfficientNetB1/model_224.h5
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 195ms/step - AUC: 0.9925 - accuracy: 0.9662 - loss: 0.1040 - val_AUC: 0.5044 - val_accuracy: 0.1673 - val_loss: 1.8830 - learning_rate: 0.0010
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9883 - accuracy: 0.9550 - loss: 0.1470
# Epoch 7: val_loss did not improve from 1.88299
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - AUC: 0.9883 - accuracy: 0.9551 - loss: 0.1469 - val_AUC: 0.6431 - val_accuracy: 0.3308 - val_loss: 2.0113 - learning_rate: 0.0010
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9915 - accuracy: 0.9766 - loss: 0.0750
# Epoch 8: val_loss did not improve from 1.88299
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 185ms/step - AUC: 0.9914 - accuracy: 0.9765 - loss: 0.0753 - val_AUC: 0.4917 - val_accuracy: 0.1879 - val_loss: 94.7329 - learning_rate: 0.0010
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9818 - accuracy: 0.9489 - loss: 0.1790
# Epoch 9: val_loss did not improve from 1.88299
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 186ms/step
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9961 - accuracy: 0.9980 - loss: 0.0095
# Epoch 22: val_loss did not improve from 0.27085
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 184ms/step - AUC: 0.9961 - accuracy: 0.9980 - loss: 0.0095 - val_AUC: 0.9805 - val_accuracy: 0.9369 - val_loss: 0.2879 - learning_rate: 1.0000e-05
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9957 - accuracy: 0.9982 - loss: 0.0077
# Epoch 23: val_loss did not improve from 0.27085
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - AUC: 0.9957 - accuracy: 0.9982 - loss: 0.0077 - val_AUC: 0.9805 - val_accuracy: 0.9369 - val_loss: 0.2838 - learning_rate: 1.0000e-05
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - AUC: 0.9959 - accuracy: 0.9960 - loss: 0.0090
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 24: val_loss did not improve from 0.27085
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 184ms/step - AUC: 0.9959 - accuracy: 0.9960 - loss: 0.0090 - val_AUC: 0.9805 - val_accuracy: 0.9305 - val_loss: 0.2783 - learning_rate: 1.0000e-05
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - AUC: 0.9961 - accuracy: 0.9989 - loss: 0.0064
# Epoch 25: val_loss did not improve from 0.27085
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 184ms/step - AUC: 0.9961 - accuracy: 0.9989 - loss: 0.0064 - val_AUC: 0.9802 - val_accuracy: 0.9356 - val_loss: 0.2827 - learning_rate: 1.0000e-06
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9951 - accuracy: 0.9970 - loss: 0.0079
# Epoch 26: val_loss did not improve from 0.27085
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - AUC: 0.9951 - accuracy: 0.9970 - loss: 0.0079 - val_AUC: 0.9805 - val_accuracy: 0.9369 - val_loss: 0.2818 - learning_rate: 1.0000e-06
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - AUC: 0.9962 - accuracy: 0.9970 - loss: 0.0107
# Epoch 27: val_loss did not improve from 0.27085
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 185ms/step - AUC: 0.9962 - accuracy: 0.9970 - loss: 0.0107 - val_AUC: 0.9809 - val_accuracy: 0.9356 - val_loss: 0.2827 - learning_rate: 1.0000e-06
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9960 - accuracy: 0.9976 - loss: 0.0114
# Epoch 28: val_loss did not improve from 0.27085
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 185ms/step - AUC: 0.9960 - accuracy: 0.9976 - loss: 0.0113 - val_AUC: 0.9806 - val_accuracy: 0.9356 - val_loss: 0.2843 - learning_rate: 1.0000e-06
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - AUC: 0.9950 - accuracy: 0.9971 - loss: 0.0087
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 29: val_loss did not improve from 0.27085
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 18s 185ms/step - AUC: 0.9950 - accuracy: 0.9971 - loss: 0.0087 - val_AUC: 0.9805 - val_accuracy: 0.9356 - val_loss: 0.2830 - learning_rate: 1.0000e-06
# Epoch 29: early stopping
# CPU times: user 9min 10s, sys: 45.7 s, total: 9min 56s
# Wall time: 12min 5s

# %% [markdown]
# ### 4.4 *Plotting*

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

# %%
pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.show()

# %% [markdown]
# ### 4.5 *Evaluate Model*

# %%
results = model.evaluate(test_images, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.24344
# Test Accuracy: 93.75%

# %% [markdown]
# ## **BOOM!! Test accuracy ~93% 💥💯**

# %% [markdown]
# # *Step 5: Prediction*

# %%
# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 5 predictions: {pred[:5]}')
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 19s 831ms/step
# The first 5 predictions: ['rose', 'tulip', 'rose', 'dandelion', 'tulip']

# %% [markdown]
# ### 5.1 *Classification Report*

# %%
y_test = list(test_df.Label)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#        daisy       0.99      0.89      0.94        90
#    dandelion       0.95      0.96      0.96       101
#         rose       0.96      0.91      0.93        77
#    sunflower       0.91      0.96      0.94        75
#        tulip       0.89      0.97      0.92        89
#
#     accuracy                           0.94       432
#    macro avg       0.94      0.94      0.94       432
# weighted avg       0.94      0.94      0.94       432

# %% [markdown]
# ### 5.2 *Confusion Matrix*

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cf_matrix = confusion_matrix(y_test, pred, normalize='true')
plt.figure(figsize = (10,6))
sns.heatmap(cf_matrix, annot=True, xticklabels = sorted(set(y_test)), yticklabels = sorted(set(y_test)))
plt.title('Normalized Confusion Matrix')
plt.show()

# %% [markdown]
# ### 5.3 *Visualize Predictions*

# %%
# Display 15 picture of the dataset with their labels
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(15, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df.Filepath.iloc[i]))
    ax.set_title(f"True: {test_df.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Awesome!! You can see RESULT mate. 🎉✨**

# %% [markdown]
# # *Step 6: Conclusion*

# %% [markdown]
# ## **Thank you for reading! If you find this notebook helpful, please do upvote and follow! 🌟 And if you want to use any part of my notebook, you're welcome to! 📝**

# %% [markdown]
# ----
